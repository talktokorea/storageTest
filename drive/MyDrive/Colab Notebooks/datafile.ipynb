# %% [markdown]
# 로컬 폴더에서 코랩으로 파일 로딩하기

# %%
from google.colab import files
file_uploaded = files.upload()

# %% [markdown]
# pandas dataframe으로 변경하기

# %%
#io  Python's main facilities for dealing with various types of IO
import io
import pandas as pd
df = pd.read_csv(io.BytesIO(file_uploaded['산업기술분류표.csv']),encoding='cp949')
df.head()
