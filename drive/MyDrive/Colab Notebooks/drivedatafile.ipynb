# %% [markdown]
# 구글 드라이브에서 코랩으로 데이터 파일 로딩하기

# %%
from google.colab import drive
drive._mount('/content/drive')

# %% [markdown]
# 경로복사한 내용 (Ctrl + V)
# /content/drive/MyDrive/산업기술분류표.csv

# %%
#io  Python's main facilities for dealing with various types of IO
import io
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/산업기술분류표.csv',encoding='cp949')
df.head()

# %% [markdown]
# python의 os를 이용한 파일 탐색 방법

# %% [markdown]
# 현재 디렉토리 위치

# %%
import os
os.getcwd()

# %% [markdown]
# 디렉토리 리스트

# %%
os.listdir()

# %% [markdown]
# 파일 유무

# %%
os.path.isfile('/content/drive/MyDrive/산업기술분류표.csv')

# %% [markdown]
# 이미지 경로 확인
# /content/drive/MyDrive/Colab Notebooks/data/산업분류/profile.png

# %%
img_dir='/content/drive/MyDrive/Colab Notebooks/data/산업분류'
from keras.preprocessing  import image
img=image.load_img(os.path.join(img_dir,'profile.png'),target_size=(200,200))
import matplotlib.pyplot as plt
plt.imshow(img)
plt.show()
